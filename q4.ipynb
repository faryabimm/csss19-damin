# %%
import pandas as pd
from src.hypothesis_test import *
from src.modules import *
import warnings
warnings.filterwarnings('ignore')
lung_cancer = pd.read_csv('datasets/lung_cancer.csv')

# %% [markdown]
# <div style="direction:rtl;line-height:300%;"><font face="IRANSans" size=5>
# <font color=red size=7>
# <p></p>
# <div align=center>بخش ۴ </div>
# </font></div>
# <hr/><hr/>

# %% [markdown]
# <div style="direction:rtl;line-height:150%;"><font face="IRANSans" size=3>
#     بخشی از دیتاست رو در زیر میتونید مشاهده کنید.
# </font></div>

# %%
head(lung_cancer)
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %% [markdown]
# <div style="direction:rtl;line-height:150%;"><font face="IRANSans" size=3>
#     نمودار چگالی تعداد بار سیگار کشیدن را برای افراد بیمار در زیر مشاهده کنید.
# </font></div>

# %%
density(lung_cancer, ['Smokes'], bin_size = 5, criteria='Result == 1')

# %% [markdown]
# <div style="direction:rtl;line-height:150%;"><font face="IRANSans" size=3>
#     نمودار چگالی تعداد بار سیگار کشیدن را برای افراد سالم در زیر مشاهده کنید.
#     <br>
#      با توجه به این دو نمودار چه فرض دارید؟
# </font></div>

# %%
density(lung_cancer, ['Smokes'], bin_size = 5, criteria='Result == 0')

# %% [markdown]
# <div style="direction:rtl;line-height:150%;"><font face="IRANSans" size=3>
#     با کمک منتورها، برای آزمون فرض خود از کل داده ها چند بار داده ها را به دو دسته تصادفی تقسیم کنید و میانگین آنها را بررسی کنید.
#     <br>
#      برای این کار از تابع
#     <code>random_grouping</code>
#     استفاده کنید.
# </font></div>

# %%
random_grouping(lung_cancer, "Result", "Smokes")

# %% [markdown]
# <div style="direction:rtl;line-height:150%;"><font face="IRANSans" size=3>
#     حالا با کمک تابع
#     <code>permutation_test</code>
#     نمودار کل اختلاف میانگین های دو دسته را رسم کنید.
# </font></div>

# %%
permutation_test(lung_cancer, "Result", "Smokes")
# Out:
# There are 242 times in 1000 times that we have mean difference greater or equal to our data's mean difference
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-aa45048854ae> in <module>
# ----> 1 permutation_test(lung_cancer, "Result", "Smokes")
#
# /damin/src/hypothesis_test.py in permutation_test(df, group, info)
#      50         res.append(differ)
#      51     print("There are "+str(counter)+" times in 1000 times that we have mean difference greater or equal to our data's mean difference")
# ---> 52     px.histogram(res).show()
#      53
#      54
#
# /usr/local/lib/python3.7/site-packages/plotly/express/_chart_types.py in histogram(data_frame, x, y, color, facet_row, facet_col, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, title, template, width, height)
#     353             bingroup="x" if orientation == "v" else "y",
#     354         ),
# --> 355         layout_patch=dict(barmode=barmode, barnorm=barnorm),
#     356     )
#     357
#
# /usr/local/lib/python3.7/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#     867
#     868     trace_specs, grouped_mappings, sizeref, show_colorbar = infer_config(
# --> 869         args, constructor, trace_patch
#     870     )
#     871     grouper = [x.grouper or one_group for x in grouped_mappings] or [one_group]
#
# /usr/local/lib/python3.7/site-packages/plotly/express/_core.py in infer_config(args, constructor, trace_patch)
#     732     # Validate that the strings provided as attribute values reference columns
#     733     # in the provided data_frame
# --> 734     df_columns = args["data_frame"].columns
#     735
#     736     for attr in attrables + group_attrables + ["color"]:
#
# AttributeError: 'list' object has no attribute 'columns'

# %% [markdown]
# <div style="direction:rtl;line-height:150%;"><font face="IRANSans" size=3>
# نمودار را تحلیل کنید.
# </font></div>
