# %%
import pandas as pd
from src.modules import *
import warnings
warnings.filterwarnings('ignore')
imdb = pd.read_csv('datasets/imdb_final.csv', index_col=None)

# %% [markdown]
# <div style="direction:rtl;line-height:300%;"><font face="IRANSans" size=5>
# <font color=red size=7>
# <p></p>
# <div align=center>بخش ۲ </div>
# </font>
# <hr>
# <div style="direction:rtl;line-height:110%;"><font face="IRANSans" size=3>
# دیتاست مربوط به فیلم‌های سال ۲۰۰۶ تا ۲۰۱۶ در سایت IMDB به شما داده شده است.در این قسمت قصد داریم که مثل یک دانشمند علوم داده‌ی واقعی، با بهره‌گیری از کنجکاوی خود، از این دیتاست اطلاعاتی استخراج کنیم!
# پیش از هرچیز، با کمک دستور
#     <code>head</code>
#     چندتا از داد‌های این دیتاست را مشاهده کنید.
# </font></div>
# </font></div>

# %%
head(imdb)
# Out:
#                      Title      Genre              Director  Year  Runtime  \
# 0  Guardians of the Galaxy     Action            James Gunn  2014      121
# 1               Prometheus  Adventure          Ridley Scott  2012      124
# 2                    Split     Horror    M. Night Shyamalan  2016      117
# 3                     Sing  Animation  Christophe Lourdelet  2016      108
# 4            Suicide Squad     Action            David Ayer  2016      123
#
#    Rating   Votes  Revenue  Metascore
# 0     8.1  757074   333.13       76.0
# 1     7.0  485820   126.46       65.0
# 2     7.3  157606   138.12       62.0
# 3     7.2   60545   270.32       59.0
# 4     6.2  393727   325.02       40.0

# %% [markdown]
# <div style="direction:rtl;line-height:200%;"><font face="IRANSans" size=3>
# ستون‌های دیتاست این‌ها هستند:
# <br/>
#   <lu>
#     Title: نام فیلم
#     </lu>
#     <br>
#     <lu>
#     Genre: ژانر
#     </lu>
#     <br>
#     <lu>
#     Director: کارگردان
#     </lu>
#     <br>
#     <lu>
#     Year: سال تولید
#     </lu>
#     <br>
#     <lu>
#     Runtime: مدت فیلم(دقیقه)
#     </lu>
#     <br>
#     <lu>
#     Rating: امتیاز
#     </lu>
#     <br>
#     <lu>
#    Votes: تعداد آرا
#     </lu>
#     <br>
#     <lu>
#     Revenue: میزان فروش
#     </lu>
#     <br>
#     <lu>
#     Metascore:امتیاز منتقدین
#     </lu>
# </font></div>

# %% [markdown]
# <div style="direction:rtl;line-height:110%;"><font face="IRANSans" size=3>
#     با استفاده از برگه‌ای که در ابتدای کارگاه به شما داده شده، و با کمک منتورها، سوالات مربوط به دیتاست را در اینجا پاسخ دهید:
# </font></div>
